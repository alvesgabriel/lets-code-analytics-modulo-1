# %%
import pandas as pd
import seaborn

# %%
filename = 'AgeDataset-V1.csv'

# %%
df = pd.read_csv(filename)
df
# Out:
#                 Id                     Name  \
# 0              Q23        George Washington
# 1              Q42            Douglas Adams
# 2              Q91          Abraham Lincoln
# 3             Q254  Wolfgang Amadeus Mozart
# 4             Q255     Ludwig van Beethoven
# ...            ...                      ...
# 1223004  Q77247326    Marie-Fortunée Besson
# 1223005  Q77249504              Ron Thorsen
# 1223006  Q77249818       Diether Todenhagen
# 1223007  Q77253909  Reginald Oswald Pearson
# 1223008  Q77254864             Horst Lerche
#
#                                          Short description Gender  \
# 0           1st president of the United States (1732–1799)   Male
# 1                              English writer and humorist   Male
# 2          16th president of the United States (1809-1865)   Male
# 3                Austrian composer of the Classical period   Male
# 4                   German classical and romantic composer   Male
# ...

# %%
df.shape
# Out:
# (1223009, 10)

# %% [markdown]
# 1. Comparação entre sexos
# 1. Ano com maior quantidade de mortes
# 1. Longevidade
# 1. Clube dos 27 (pessoas que morreram com 27 anos)
# 1. Ocupação
# 1. Quantidade de mortes por causa
# 1. Causa da Morte VS Ocupação
# 1. Ocupação VS Longevidade

# %%
df.head(100)
# Out:
#        Id                     Name  \
# 0     Q23        George Washington
# 1     Q42            Douglas Adams
# 2     Q91          Abraham Lincoln
# 3    Q254  Wolfgang Amadeus Mozart
# 4    Q255     Ludwig van Beethoven
# ..    ...                      ...
# 95  Q1064       Alessandro Manzoni
# 96  Q1067          Dante Alighieri
# 97  Q1145     Jean-Philippe Rameau
# 98  Q1149            Indira Gandhi
# 99  Q1151           Hector Berlioz
#
#                                    Short description  Gender  \
# 0     1st president of the United States (1732–1799)    Male
# 1                        English writer and humorist    Male
# 2    16th president of the United States (1809-1865)    Male
# 3          Austrian composer of the Classical period    Male
# 4             German classical and romantic composer    Male
# ..                                               ...     ...
# 95             Italian poet and novelist (1785-1873)    Male
# ...

# %% [markdown]
# # Tratamento do dataset

# %% [markdown]
# Exclusão de linhas duplicadas

# %%
## Conferindo todos os dados duplicados
df[df.duplicated(keep=False)]
# Out:
#                Id                  Name  \
# 974969  Q21604253  August Mercadé Ramon
# 974970  Q21604253  August Mercadé Ramon
# 996218  Q23648966       Andrée Dupeyron
# 996219  Q23648966       Andrée Dupeyron
#
#                                    Short description  Gender Country  \
# 974969  Spanish economist and journalist (1909-1967)    Male   Spain
# 974970  Spanish economist and journalist (1909-1967)    Male   Spain
# 996218                                French aviator  Female  France
# 996219                                French aviator  Female  France
#
#                 Occupation  Birth year  Death year Manner of death  \
# 974969      Businessperson        1909      1967.0             NaN
# 974970      Businessperson        1909      1967.0             NaN
# 996218  Military personnel        1902      1988.0             NaN
# 996219  Military personnel        1902      1988.0             NaN
#
#         Age of death
# 974969          58.0
# 974970          58.0
# ...

# %%
## Excluindo os dados
df = df.drop_duplicates(keep='first')
##Coferindo exclusão
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Id, Name, Short description, Gender, Country, Occupation, Birth year, Death year, Manner of death, Age of death]
# Index: []
