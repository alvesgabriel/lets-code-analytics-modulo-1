# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Faz a leitura do CSV
df = pd.read_csv('AgeDatasetClean.csv', sep = '|')
df
# Out:
#                            Name  \
# 0             George Washington
# 1                 Douglas Adams
# 2               Abraham Lincoln
# 3       Wolfgang Amadeus Mozart
# 4          Ludwig van Beethoven
# ...                         ...
# 732956             Wim de Vreng
# 732957            James Smillie
# 732958             Gustav Siber
# 732959  Reginald Oswald Pearson
# 732960             Horst Lerche
#
#                                         Short description Gender  \
# 0          1st president of the United States (1732–1799)   Male
# 1                             English writer and humorist   Male
# 2         16th president of the United States (1809-1865)   Male
# 3               Austrian composer of the Classical period   Male
# 4                  German classical and romantic composer   Male
# ...                                                   ...    ...
# 732956                                      Dutch swimmer   Male
# 732957                 goudsmid uit Schotland (1784-1841)   Male
# 732958                      entrepreneur from Switzerland   Male
# 732959  English artist, working in stained glass, prin...   Male
# 732960                                     German painter   Male
#
#                                                   Country    Occupation  \
# 0       United States of America; Kingdom of Great Bri...    Politician
# 1                                          United Kingdom        Artist
# 2                                United States of America    Politician
# 3         Archduchy of Austria; Archbishopric of Salzburg        Artist
# 4                      Holy Roman Empire; Austrian Empire        Artist
# ...                                                   ...           ...
# 732956                         Kingdom of the Netherlands       Athlete
# 732957                                           Scotland     Goldsmith
# 732958                                        Switzerland  Entrepreneur
# 732959                                     United Kingdom        Artist
# 732960                                            Germany        Artist
#
#         Birth year  Death year  Age of death
# 0             1732      1799.0          67.0
# 1             1952      2001.0          49.0
# 2             1809      1865.0          56.0
# 3             1756      1791.0          35.0
# 4             1770      1827.0          57.0
# ...            ...         ...           ...
# 732956        1930      1980.0          50.0
# 732957        1784      1841.0          57.0
# 732958        1857      1924.0          67.0
# 732959        1887      1915.0          28.0
# 732960        1938      2017.0          79.0
#
# [732961 rows x 8 columns]

# %%
## Verificando as linhas duplicadas 
df[df.duplicated()]
# Out:
#                         Name                             Short description  \
# 660898  August Mercadé Ramon  Spanish economist and journalist (1909-1967)
# 668982       Andrée Dupeyron                                French aviator
#
#         Gender Country          Occupation  Birth year  Death year  \
# 660898    Male   Spain      Businessperson        1909      1967.0
# 668982  Female  France  Military personnel        1902      1988.0
#
#         Age of death
# 660898          58.0
# 668982          86.0

# %%
## Remove as duplicadas
df.drop_duplicates(inplace=True)

# %%
## Verifica os as ocupacoes
df['Occupation'].value_counts()
# Out:
# Artist                                                     207322
# Politician                                                 152916
# Athlete                                                     92645
# Researcher                                                  63799
# Military personnel                                          36024
#                                                             ...
# Ballet dancer; choreographer; french resistance fighter         1
# Master craftsman; chair-maker; furniture designer               1
# Stevedore; civil libertarianism                                 1
# Mountaineer; paraglider pilot                                   1
# Director; scout leader                                          1
# Name: Occupation, Length: 7750, dtype: int64

# %%
#Funcao para evidenciar as linhas com 2 ou mais ocupacoes declaradas
df['Occupation Count'] = df['Occupation'].apply(lambda x: len(x.split(";"))).astype('int')

# %%
df[df['Occupation Count'] > 2]
# Out:
#                             Name  \
# 536                   James Cook
# 537                Hernán Cortés
# 605     Emperor Shenzong of Song
# 771     Diana, Princess of Wales
# 1262                  Odo Bujwid
# ...                          ...
# 731205              Albert Razin
# 731515      Innocent-Vincze Ernő
# 732074               Vera Collum
# 732395             Margaret Auld
# 732494    Manuel Bartual Verdejo
#
#                                         Short description  Gender  \
# 536                           British explorer, navigator    Male
# 537                                  Spanish conquistador    Male
# 605              6th emperor of the Northern Song Dynasty    Male
# 771     first wife of Charles, Prince of Wales (1961-1...  Female
# 1262                     Polish biologist and esperantist    Male
# ...                                                   ...     ...
# 731205  Russian ethnographer and Udmurt language activist    Male
# 731515               Hongaars toneelschrijver (1903-1978)    Male
# 732074              British suffragist and anthropologist  Female
# 732395  Scottish nurse, Matron and Chief Nursing Offic...  Female
# 732494        Spanish mechanic, drafter and revolutionary    Male
#
#                                       Country  \
# 536                  Kingdom of Great Britain
# 537     Spain; Spanish Empire; Habsburg Spain
# 605                              Song dynasty
# 771                            United Kingdom
# 1262                                   Poland
# ...                                       ...
# 731205                   Russia; Soviet Union
# 731515                                Hungary
# 732074                         United Kingdom
# 732395                               Scotland
# 732494                                  Spain
#
#                                                Occupation  Birth year  \
# 536       Cartographer; naval officer; explorer; seafarer        1728
# 537                      Conquistador; governor; explorer        1485
# 605                            Monarch; ruler; aristocrat        1048
# 771     Socialite; environmentalist; philanthropist; h...        1961
# 1262               Esperantist; biologist; microbiologist        1857
# ...                                                   ...         ...
# 731205  Public figure; sociologist; philosopher; ethno...        1940
# 731515                   Playwright; dramaturge; lyricist        1903
# 732074           Radiographer; anthropologist; suffragist        1883
# 732395                       Nurse; civil servant; matron        1932
# 732494                   Mechanic; drafter; revolutionary        1844
#
#         Death year  Age of death  Occupation Count
# 536         1779.0          51.0                 4
# 537         1547.0          62.0                 3
# 605         1085.0          37.0                 3
# 771         1997.0          36.0                 4
# 1262        1942.0          85.0                 3
# ...            ...           ...               ...
# 731205      2019.0          79.0                 5
# 731515      1978.0          75.0                 3
# 732074      1957.0          74.0                 3
# 732395      2010.0          78.0                 3
# 732494      1886.0          42.0                 3
#
# [1922 rows x 9 columns]

# %%
df['Occupation Count'].value_counts()
# Out:
# 1    721078
# 2      9959
# 3      1569
# 4       272
# 5        66
# 6        10
# 7         4
# 8         1
# Name: Occupation Count, dtype: int64

# %%
#Dropas as linhas com 2 ou mais ocupacoees declaradas
df.drop(df[df['Occupation'].apply(lambda x: len(x.split(';'))) > 1].index, inplace=True)

# %%
## Verifica os as ocupacoes novamente doublecheck
df['Occupation'].value_counts()
# Out:
# Artist                207322
# Politician            152916
# Athlete                92645
# Researcher             63799
# Military personnel     36024
#                        ...
# Executive producer         1
# Childcare worker           1
# Molfar                     1
# Tipster                    1
# Radiographer               1
# Name: Occupation, Length: 1944, dtype: int64

# %%
#busca as 10 ocupacoes que mais aparecem
top_occupation = df['Occupation'].value_counts()[:10]

# %%
top_occupation
# Out:
# Artist                207322
# Politician            152916
# Athlete                92645
# Researcher             63799
# Military personnel     36024
# Religious figure       18538
# Architect              12588
# Businessperson         12107
# Journalist             10929
# Teacher                10769
# Name: Occupation, dtype: int64
